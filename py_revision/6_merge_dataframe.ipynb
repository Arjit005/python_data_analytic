# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset

# %%
dataset=load_dataset('lukebarousse/data_jobs')
df=dataset['train'].to_pandas()

# %%
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

df_us = df[df['job_country'] == 'United States'].copy()
df_us['job_posted_month'] = df_us['job_posted_date'].dt.strftime('%B')

df_us_pivot = df_us.pivot_table(
    index='job_posted_month',
    columns='job_title_short',
    aggfunc='size'
).reset_index()

df_us_pivot['month_no'] = pd.to_datetime(df_us_pivot['job_posted_month'], format='%B').dt.month
df_us_pivot = df_us_pivot.sort_values('month_no')
df_us_pivot = df_us_pivot.set_index('job_posted_month')
df_us_pivot = df_us_pivot.drop(columns='month_no')

df_us_pivot
# Out:
# job_title_short   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# January                        527              36          8494
# February                       447              24          6124
# March                          438              19          6218
# April                          565              40          6049
# May                            279              20          4993
# June                           446              32          5683
# July                           581              39          5201
# August                         903              39          6634
# September                      897              50          4639
# October                        932              48          5271
# November                       719              36          4531
# December                       648              40          3979
#
# job_title_short   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# ...

# %%
pd.read_csv('https://lukeb.co/software_csv')
# Out:
#    job_posted_month  Front-End Developer  Back-End Developer  \
# 0           January                13619                9827
# 1          February                11456                9116
# 2             March                11102                8178
# 3             April                14037                9209
# 4               May                12126                8864
# 5              June                12003                8065
# 6              July                11914                8061
# 7            August                11571                8191
# 8         September                14016                8447
# 9           October                11419                8476
# 10         November                13771                9034
# 11         December                14033                9232
#
#     Full-Stack Developer  UI/UX Designer
# 0                   5108            4348
# 1                   7298            4284
# 2                   5814            4159
# ...

# %%
us_software_pivot=pd.read_csv('https://lukeb.co/software_csv',index_col='job_posted_month')

# %%
us_software_pivot
# Out:
#                   Front-End Developer  Back-End Developer  \
# job_posted_month
# January                         13619                9827
# February                        11456                9116
# March                           11102                8178
# April                           14037                9209
# May                             12126                8864
# June                            12003                8065
# July                            11914                8061
# August                          11571                8191
# September                       14016                8447
# October                         11419                8476
# November                        13771                9034
# December                        14033                9232
#
#                   Full-Stack Developer  UI/UX Designer
# job_posted_month
# January                           5108            4348
# February                          7298            4284
# ...

# %%
df_us_pivot.merge(us_software_pivot,on='job_posted_month')
# Out:
#                   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# January                        527              36          8494
# February                       447              24          6124
# March                          438              19          6218
# April                          565              40          6049
# May                            279              20          4993
# June                           446              32          5683
# July                           581              39          5201
# August                         903              39          6634
# September                      897              50          4639
# October                        932              48          5271
# November                       719              36          4531
# December                       648              40          3979
#
#                   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# ...

# %%
df_us_merged=df_us_pivot.merge(us_software_pivot,on='job_posted_month')

# %%
top_5=df_us_merged.sum()# already using pivot table
top_5
# Out:
# Business Analyst               7382
# Cloud Engineer                  423
# Data Analyst                  67816
# Data Engineer                 35080
# Data Scientist                58830
# Machine Learning Engineer       921
# Senior Data Analyst           11791
# Senior Data Engineer           9289
# Senior Data Scientist         12946
# Software Engineer              1814
# Front-End Developer          151067
# Back-End Developer           104700
# Full-Stack Developer          75873
# UI/UX Designer                52169
# dtype: int64

# %%
df_us_merged.plot(kind='line')
plt.legend()
plt.show()
